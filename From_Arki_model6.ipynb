# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-autoencoder/blob/main/From_Arki_model6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 61
size = 128

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.25):
        for i in np.arange(0,int(width/size)+1,0.25):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data




train_input = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_input_train.png"))))
print("Done reading the  training input of size = ", train_input.shape)

train_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output_train.png"))))
print("Done reading the  training out of size = ", train_output.shape)

test_input = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_input_test.png"))))
print("Done reading the  test input of size = ", test_input.shape)

test_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output_test.png"))))
print("Done reading the  test output of size = ", test_output.shape)
# Out:
# Done reading the  training input of size =  (17136, 128, 128)
# Done reading the  training out of size =  (17136, 128, 128)
# Done reading the  test input of size =  (7200, 128, 128)
# Done reading the  test output of size =  (7200, 128, 128)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+2000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+2000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=1)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(64, kernel_size=3, strides=1, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()



autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_' + str(model_number)+'.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_' + str(model_number)+'.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 536/536 [==============================] - 42s 56ms/step - loss: 0.0299 - val_loss: 0.0209
# Epoch 2/100
# 536/536 [==============================] - 25s 47ms/step - loss: 0.0194 - val_loss: 0.0185
# Epoch 3/100
# 536/536 [==============================] - 27s 51ms/step - loss: 0.0181 - val_loss: 0.0182
# Epoch 4/100
# 536/536 [==============================] - 26s 48ms/step - loss: 0.0176 - val_loss: 0.0182
# Epoch 5/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0173 - val_loss: 0.0178
# Epoch 6/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0171 - val_loss: 0.0173
# Epoch 7/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0168 - val_loss: 0.0172
# Epoch 8/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0167 - val_loss: 0.0172
# Epoch 9/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0166 - val_loss: 0.0171
# Epoch 10/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0164 - val_loss: 0.0169
# Epoch 11/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0163 - val_loss: 0.0168
# Epoch 12/100
# 536/536 [==============================] - 27s 49ms/step - loss: 0.0161 - val_loss: 0.0166
# Epoch 13/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0160 - val_loss: 0.0165
# Epoch 14/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0158 - val_loss: 0.0165
# Epoch 15/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0158 - val_loss: 0.0162
# Epoch 16/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0156 - val_loss: 0.0165
# Epoch 17/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0156 - val_loss: 0.0162
# Epoch 18/100
# 536/536 [==============================] - 27s 50ms/step - loss: 0.0155 - val_loss: 0.0162
# Epoch 19/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0154 - val_loss: 0.0162
# Epoch 20/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0154 - val_loss: 0.0165
# Epoch 21/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0153 - val_loss: 0.0167
# Epoch 22/100
# 536/536 [==============================] - 27s 49ms/step - loss: 0.0153 - val_loss: 0.0159
# Epoch 23/100
# 536/536 [==============================] - 27s 50ms/step - loss: 0.0152 - val_loss: 0.0161
# Epoch 24/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0152 - val_loss: 0.0163
# Epoch 25/100
# 536/536 [==============================] - 27s 50ms/step - loss: 0.0152 - val_loss: 0.0160
# Epoch 26/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0152 - val_loss: 0.0159
# Epoch 27/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0151 - val_loss: 0.0163
# Epoch 28/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0151 - val_loss: 0.0161
# Epoch 29/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0151 - val_loss: 0.0160
# Epoch 30/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0151 - val_loss: 0.0160
# Epoch 31/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0151 - val_loss: 0.0158
# Epoch 32/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0150 - val_loss: 0.0161
# Epoch 33/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0150 - val_loss: 0.0159
# Epoch 34/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0150 - val_loss: 0.0159
# Epoch 35/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0150 - val_loss: 0.0159
# Epoch 36/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0150 - val_loss: 0.0162
# Epoch 37/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0149 - val_loss: 0.0160
# Epoch 38/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0149 - val_loss: 0.0159
# Epoch 39/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0149 - val_loss: 0.0159
# Epoch 40/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0149 - val_loss: 0.0158
# Epoch 41/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0149 - val_loss: 0.0158
# Epoch 42/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0149 - val_loss: 0.0159
# Epoch 43/100
# 536/536 [==============================] - 27s 49ms/step - loss: 0.0148 - val_loss: 0.0157
# Epoch 44/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0148 - val_loss: 0.0160
# Epoch 45/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0148 - val_loss: 0.0159
# Epoch 46/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 47/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 48/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 49/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 50/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 51/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 52/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0148 - val_loss: 0.0159
# Epoch 53/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 54/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 55/100
# 536/536 [==============================] - 27s 49ms/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 56/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0147 - val_loss: 0.0159
# Epoch 57/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 58/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 59/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 60/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 61/100
# 536/536 [==============================] - 27s 50ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 62/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0146 - val_loss: 0.0159
# Epoch 63/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0146 - val_loss: 0.0157
# Epoch 64/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0146 - val_loss: 0.0157
# Epoch 65/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0146 - val_loss: 0.0158
# Epoch 66/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0146 - val_loss: 0.0157
# Epoch 67/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0146 - val_loss: 0.0158
# Epoch 68/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0146 - val_loss: 0.0157
# Epoch 69/100
# 536/536 [==============================] - 28s 52ms/step - loss: 0.0146 - val_loss: 0.0157
# Epoch 70/100
# 536/536 [==============================] - 27s 50ms/step - loss: 0.0146 - val_loss: 0.0157
# Epoch 71/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0146 - val_loss: 0.0158
# Epoch 72/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0146 - val_loss: 0.0157
# Epoch 73/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0146 - val_loss: 0.0158
# Epoch 74/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0146 - val_loss: 0.0157
# Epoch 75/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 76/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 77/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 78/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 79/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0145 - val_loss: 0.0158
# Epoch 80/100
# 536/536 [==============================] - 27s 50ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 81/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 82/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 83/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 84/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 85/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 86/100
# 536/536 [==============================] - 27s 49ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 87/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 88/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 89/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 90/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 91/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0145 - val_loss: 0.0155
# Epoch 92/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0145 - val_loss: 0.0157
# Epoch 93/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 94/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0144 - val_loss: 0.0157
# Epoch 95/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0144 - val_loss: 0.0156
# Epoch 96/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0144 - val_loss: 0.0156
# Epoch 97/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0144 - val_loss: 0.0155
# Epoch 98/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0144 - val_loss: 0.0157
# Epoch 99/100
# 536/536 [==============================] - 28s 53ms/step - loss: 0.0144 - val_loss: 0.0157
# Epoch 100/100
# 536/536 [==============================] - 26s 49ms/step - loss: 0.0144 - val_loss: 0.0157
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      640
#
# =================================================================
# Total params: 640 (2.50 KB)
# Trainable params: 640 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 2792.2598481178284 seconds

# %%
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# The time of execution of above program is : 1237.8102622032166 seconds
