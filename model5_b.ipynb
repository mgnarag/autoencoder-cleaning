# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-autoencoder/blob/main/model5_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/one quadrant/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 5
size = 128

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.3775):
        for i in np.arange(0,int(width/size)+1,0.3775):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data



'''
train_input = np.array(crop(Image.open(file_path + "final_input_train.png")))
print("Done reading the  training input of size = ", train_input.shape)

train_output = np.array(crop(Image.open(file_path + "cleaned_output_train.png")))
print("Done reading the  training out of size = ", train_output.shape)

test_input = np.array(crop(Image.open(file_path + "final_input_test.png")))
print("Done reading the  test input of size = ", test_input.shape)

test_output = np.array(crop(Image.open(file_path + "cleaned_output_test.png")))
print("Done reading the  test output of size = ", test_output.shape)
'''

train_input = np.array(crop(ImageOps.grayscale(Image.open(file_path + "final_input_train.png"))))
print("Done reading the  training input of size = ", train_input.shape)

train_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "cleaned_output_train.png"))))
print("Done reading the  training out of size = ", train_output.shape)

test_input = np.array(crop(ImageOps.grayscale(Image.open(file_path + "final_input_test.png"))))
print("Done reading the  test input of size = ", test_input.shape)

test_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "cleaned_output_test.png"))))
print("Done reading the  test output of size = ", test_output.shape)
#'''
# Out:
# Done reading the  training input of size =  (22484, 128, 128)
# Done reading the  training out of size =  (22484, 128, 128)
# Done reading the  test input of size =  (9394, 128, 128)
# Done reading the  test output of size =  (9394, 128, 128)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+10]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+10]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(256, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(256, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()



autoencoder.save(file_path + '1 Models/' + 'autoencoder_'+str(model_number) + '_b')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+str(model_number)+'_b'+'.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+str(model_number)+'_b'+'.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 703/703 [==============================] - 28s 21ms/step - loss: 0.0248 - val_loss: 0.0069
# Epoch 2/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 3/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0065 - val_loss: 0.0051
# Epoch 4/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 5/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 6/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 7/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 8/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 9/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 10/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 11/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 12/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0044 - val_loss: 0.0039
# Epoch 13/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0042 - val_loss: 0.0039
# Epoch 14/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 15/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 16/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 17/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 18/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 19/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 20/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 21/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 22/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0028 - val_loss: 0.0036
# Epoch 23/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 24/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 25/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 26/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 27/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 28/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 29/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 30/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 31/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 32/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0019 - val_loss: 0.0040
# Epoch 33/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 34/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0018 - val_loss: 0.0043
# Epoch 35/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 36/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0016 - val_loss: 0.0040
# Epoch 37/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0016 - val_loss: 0.0044
# Epoch 38/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0015 - val_loss: 0.0043
# Epoch 39/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0015 - val_loss: 0.0042
# Epoch 40/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0015 - val_loss: 0.0040
# Epoch 41/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 42/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 43/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 44/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 45/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 46/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 47/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 48/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 49/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 50/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 51/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 52/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 53/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0011 - val_loss: 0.0042
# Epoch 54/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 55/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0010 - val_loss: 0.0044
# Epoch 56/100
# 703/703 [==============================] - 12s 17ms/step - loss: 9.8672e-04 - val_loss: 0.0044
# Epoch 57/100
# 703/703 [==============================] - 12s 17ms/step - loss: 9.8895e-04 - val_loss: 0.0042
# Epoch 58/100
# 703/703 [==============================] - 12s 17ms/step - loss: 0.0010 - val_loss: 0.0044
# Epoch 59/100
# 703/703 [==============================] - 12s 17ms/step - loss: 9.7276e-04 - val_loss: 0.0045
# Epoch 60/100
# 703/703 [==============================] - 12s 17ms/step - loss: 9.2862e-04 - val_loss: 0.0045
# Epoch 61/100
# 703/703 [==============================] - 12s 17ms/step - loss: 9.2965e-04 - val_loss: 0.0044
# Epoch 62/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.9889e-04 - val_loss: 0.0045
# Epoch 63/100
# 703/703 [==============================] - 12s 17ms/step - loss: 9.2688e-04 - val_loss: 0.0043
# Epoch 64/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.8638e-04 - val_loss: 0.0046
# Epoch 65/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.7180e-04 - val_loss: 0.0044
# Epoch 66/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.5049e-04 - val_loss: 0.0043
# Epoch 67/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.3815e-04 - val_loss: 0.0044
# Epoch 68/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.3010e-04 - val_loss: 0.0044
# Epoch 69/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.2634e-04 - val_loss: 0.0046
# Epoch 70/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.5342e-04 - val_loss: 0.0045
# Epoch 71/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.7794e-04 - val_loss: 0.0044
# Epoch 72/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.8808e-04 - val_loss: 0.0044
# Epoch 73/100
# 703/703 [==============================] - 12s 17ms/step - loss: 8.3516e-04 - val_loss: 0.0044
# Epoch 74/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.5965e-04 - val_loss: 0.0045
# Epoch 75/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.3882e-04 - val_loss: 0.0045
# Epoch 76/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.8757e-04 - val_loss: 0.0046
# Epoch 77/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.4849e-04 - val_loss: 0.0044
# Epoch 78/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.3956e-04 - val_loss: 0.0046
# Epoch 79/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.5263e-04 - val_loss: 0.0047
# Epoch 80/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.2997e-04 - val_loss: 0.0044
# Epoch 81/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.3726e-04 - val_loss: 0.0045
# Epoch 82/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.9353e-04 - val_loss: 0.0047
# Epoch 83/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.0586e-04 - val_loss: 0.0045
# Epoch 84/100
# 703/703 [==============================] - 12s 17ms/step - loss: 7.3444e-04 - val_loss: 0.0047
# Epoch 85/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.6232e-04 - val_loss: 0.0045
# Epoch 86/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.8374e-04 - val_loss: 0.0047
# Epoch 87/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.9743e-04 - val_loss: 0.0046
# Epoch 88/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.5704e-04 - val_loss: 0.0046
# Epoch 89/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.6898e-04 - val_loss: 0.0045
# Epoch 90/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.6495e-04 - val_loss: 0.0047
# Epoch 91/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.7577e-04 - val_loss: 0.0046
# Epoch 92/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.3215e-04 - val_loss: 0.0045
# Epoch 93/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.6070e-04 - val_loss: 0.0044
# Epoch 94/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.2981e-04 - val_loss: 0.0046
# Epoch 95/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.3761e-04 - val_loss: 0.0047
# Epoch 96/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.4333e-04 - val_loss: 0.0046
# Epoch 97/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.2149e-04 - val_loss: 0.0047
# Epoch 98/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.2796e-04 - val_loss: 0.0046
# Epoch 99/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.1470e-04 - val_loss: 0.0046
# Epoch 100/100
# 703/703 [==============================] - 12s 17ms/step - loss: 6.0401e-04 - val_loss: 0.0046
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
# =================================================================
# Total params: 369,664
# Trainable params: 369,664
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# The time of execution of above program is : 1217.0694358348846 seconds
