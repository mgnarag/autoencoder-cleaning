# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/autoencoder-cleaning/blob/main/model1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/one quadrant/"

# %%
import time
import pandas as pd  


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model = 1
size = 32
 
def crop(im):
    width, height = im.size
    data = []
#    for j in range(0,int(height/28)):          #NON OVERLAPPING
#        for i in range(0,int(width/28)):
    for j in np.arange(0,int(height/size)+1,2): 
        for i in np.arange(0,int(width/size)+1,2):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data




train_input = np.array(crop(ImageOps.grayscale(Image.open(file_path + "final_input_train.png"))))
print("Done reading the  training input of size = ", train_input.shape)

train_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "cleaned_output_train.png")))) 
print("Done reading the  training out of size = ", train_output.shape)

test_input = np.array(crop(ImageOps.grayscale(Image.open(file_path + "final_input_test.png"))))
print("Done reading the  test input of size = ", test_input.shape)

test_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "cleaned_output_test.png"))))
print("Done reading the  test output of size = ", test_output.shape)
# Out:
# Done reading the  training input of size =  (12650, 32, 32)
# Done reading the  training out of size =  (12650, 32, 32)
# Done reading the  test input of size =  (5290, 32, 32)
# Done reading the  test output of size =  (5290, 32, 32)

# %%
n = 10
x=100
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((test_input[i+x]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((test_output[i+x]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

 

class autoenc(Model):
  
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])
 
  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())


model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()



autoencoder.save(file_path + '1 Models/' + 'autoencoder_1')

loss = model.history['loss']
loss = pd.DataFrame(loss) 
loss.to_csv(file_path + '2 Loss/'+'loss_1.csv') 
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss) 
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_1.csv') 

# record end time
end = time.time()
 
print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 396/396 [==============================] - 18s 9ms/step - loss: 0.0327 - val_loss: 0.0077
# Epoch 2/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0099 - val_loss: 0.0070
# Epoch 3/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0087 - val_loss: 0.0066
# Epoch 4/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0080 - val_loss: 0.0067
# Epoch 5/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0078 - val_loss: 0.0061
# Epoch 6/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0076 - val_loss: 0.0058
# Epoch 7/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 8/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0071 - val_loss: 0.0052
# Epoch 9/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0070 - val_loss: 0.0052
# Epoch 10/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0069 - val_loss: 0.0055
# Epoch 11/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0067 - val_loss: 0.0048
# Epoch 12/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0067 - val_loss: 0.0054
# Epoch 13/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0067 - val_loss: 0.0050
# Epoch 14/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0065 - val_loss: 0.0062
# Epoch 15/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0065 - val_loss: 0.0049
# Epoch 16/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 17/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0063 - val_loss: 0.0045
# Epoch 18/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0064 - val_loss: 0.0047
# Epoch 19/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 20/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0062 - val_loss: 0.0048
# Epoch 21/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0061 - val_loss: 0.0041
# Epoch 22/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 23/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 24/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0059 - val_loss: 0.0046
# Epoch 25/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0058 - val_loss: 0.0040
# Epoch 26/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 27/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 28/100
# 396/396 [==============================] - 4s 10ms/step - loss: 0.0057 - val_loss: 0.0039
# Epoch 29/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 30/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0056 - val_loss: 0.0046
# Epoch 31/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 32/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0054 - val_loss: 0.0043
# Epoch 33/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 34/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0054 - val_loss: 0.0035
# Epoch 35/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0054 - val_loss: 0.0041
# Epoch 36/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 37/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 38/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 39/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 40/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 41/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 42/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 43/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 44/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0050 - val_loss: 0.0039
# Epoch 45/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 46/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0049 - val_loss: 0.0041
# Epoch 47/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 48/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 49/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 50/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 51/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 52/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 53/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0046 - val_loss: 0.0033
# Epoch 54/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 55/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 56/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 57/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0045 - val_loss: 0.0036
# Epoch 58/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 59/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 60/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 61/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 62/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 63/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 64/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 65/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 66/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 67/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 68/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 69/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0041 - val_loss: 0.0035
# Epoch 70/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0040 - val_loss: 0.0038
# Epoch 71/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 72/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 73/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 74/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 75/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0038 - val_loss: 0.0042
# Epoch 76/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 77/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 78/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 79/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 80/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 81/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 82/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 83/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 84/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 85/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 86/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 87/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 88/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 89/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 90/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 91/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 92/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 93/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 94/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 95/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 96/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0031 - val_loss: 0.0042
# Epoch 97/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 98/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 99/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0029 - val_loss: 0.0042
# Epoch 100/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0029 - val_loss: 0.0042
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 16, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 128)         73856
#
# =================================================================
# Total params: 74,496
# Trainable params: 74,496
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# The time of execution of above program is : 324.67574739456177 seconds
